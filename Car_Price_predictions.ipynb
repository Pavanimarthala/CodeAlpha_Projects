# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df = pd.read_csv('/content/car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.shape
# Out:
# (301, 9)

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
#Check statistics of data set
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# # Data Check and Transforming

# %%
# Check null values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# Check duplication
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
# Drop duplicate values
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# checking the distribution of categorical data
print(df['Fuel_Type'].value_counts())
print(df['Selling_type'].value_counts())
print(df['Transmission'].value_counts())
# Out:
# Fuel_Type
# Petrol    239
# Diesel     58
# CNG         2
# Name: count, dtype: int64
# Selling_type
# Dealer        193
# Individual    106
# Name: count, dtype: int64
# Transmission
# Manual       260
# Automatic     39
# Name: count, dtype: int64

# %%
# encoding "Fuel_Type" Column
df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)

# encoding "Seller_Type" Column
df.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)

# encoding "Transmission" Column
df.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Selling_type  Transmission  Owner
# 0             0             0      0
# 1             0             0      0
# 2             0             0      0
# 3             0             0      0
# 4             0             0      0

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Price distribution
plt.figure(figsize=(10,6))
sns.histplot(df['Selling_Price'], kde=True)
plt.title('Car Price Distribution')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm',fmt=".2f")
plt.title('Feature Correlation')
plt.show()

# %%
# Pairplot of numerical features
sns.pairplot(df[['Selling_Price', 'Present_Price', 'Driven_kms']])
plt.show()

# %%
# Boxplots for categorical features
# Selling Price by Fuel Type
plt.figure(figsize=(10, 6))
sns.boxplot(x='Fuel_Type', y='Selling_Price', data=df)
plt.title('Selling Price by Fuel Type')
plt.show()

# Selling Price by Transmission Type
plt.figure(figsize=(10, 6))
sns.boxplot(x='Transmission', y='Selling_Price', data=df)
plt.title('Selling Price by Transmission Type')
plt.show()

# %%
# Calculate average price for each car model
avg_prices_by_car = df.groupby('Car_Name')['Selling_Price'].mean().sort_values(ascending=False)

# Plot top car models by average price
Top_car_models = avg_prices_by_car.head(15)
plt.figure(figsize=(10, 6))
sns.barplot(x=Top_car_models.values, y=Top_car_models.index)
plt.title('Top Car Models by Average Price')
plt.xlabel('Average Price')
plt.ylabel('Car Model')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Train the model

# %%
# Splitting the dataset
x = df.drop(['Car_Name','Selling_Price'],axis=1)
y = df['Selling_Price']

# %%
x
# Out:
#      Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  Transmission  \
# 0    2014           5.59       27000          0             0             0
# 1    2013           9.54       43000          1             0             0
# 2    2017           9.85        6900          0             0             0
# 3    2011           4.15        5200          0             0             0
# 4    2014           6.87       42450          1             0             0
# ..    ...            ...         ...        ...           ...           ...
# 296  2016          11.60       33988          1             0             0
# 297  2015           5.90       60000          0             0             0
# 298  2009          11.00       87934          0             0             0
# 299  2017          12.50        9000          1             0             0
# 300  2016           5.90        5464          0             0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 296      0
# 297      0
# 298      0
# 299      0
# 300      0
#
# [299 rows x 7 columns]

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# model_1 traning
model_1 = DecisionTreeRegressor()
model_1.fit(X_train, y_train)

# Prediction
y_pred = model_1.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("R^2-squared (R^2):",r2)
# Out:
# Mean Squared Error (MSE): 2.6088466666666665
# R^2-squared (R^2): 0.8824134876035918

# %%
from sklearn.ensemble import RandomForestRegressor

# model_2 training
model_2 = RandomForestRegressor()
model_2.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# prediction
y_pred = model_2.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print('Mean Squared Error:', mse)
print('R^2-squared:', r2)
# Out:
# Mean Squared Error: 1.4330239990000022
# R^2-squared: 0.9354104262332663

# %%
# Plot feature importance
feature_imps=pd.Series(model_2.feature_importances_,index=X.columns)
plt.figure(figsize=(10,8))
feature_imps.plot(kind='barh')
plt.ylabel('Features')
plt.xlabel('Importances')
plt.title('Feature Importances as per the Model')
plt.show()

# %%
pred_df=pd.DataFrame({'Actual Price':y_test,'Predicted Price':y_pred,'Difference':y_test-y_pred})
pred_df
# Out:
#      Actual Price  Predicted Price    Difference
# 265          6.50           8.1740 -1.674000e+00
# 120          1.05           0.9186  1.314000e-01
# 199          0.12           0.1849 -6.490000e-02
# 81           4.75           5.0175 -2.675000e-01
# 31           2.35           2.8390 -4.890000e-01
# 83          12.50           8.3970  4.103000e+00
# 52          18.00          15.9054  2.094600e+00
# 62          18.75          19.5530 -8.030000e-01
# 59          19.99          22.3500 -2.360000e+00
# 259          3.90           3.9635 -6.350000e-02
# 228          4.95           5.0715 -1.215000e-01
# 172          0.40           0.3909  9.100000e-03
# 160          0.45           0.4617 -1.170000e-02
# 12           7.50           7.1765  3.235000e-01
# 13           6.10           5.7325  3.675000e-01
# 213          2.90           3.4935 -5.935000e-01
# 251          5.00           5.4610 -4.610000e-01
# 297          4.00           4.1145 -1.145000e-01
# 177          0.35           0.4254 -7.540000e-02
# 194          0.20           0.4300 -2.300000e-01
# 80          14.73          11.0517  3.678300e+00
# 286          5.65           5.6290  2.100000e-02
# 174          0.38           0.3201  5.990000e-02
# 9            7.45           6.8590  5.910000e-01
# 270          4.10           4.2170 -1.170000e-01
# 130          0.75           0.6607  8.930000e-02
# 281          2.10           2.6548 -5.548000e-01
# 35           2.95           3.6780 -7.280000e-01
# 216          2.90           3.0785 -1.785000e-01
# 99           9.65           8.2730  1.377000e+00
# 47           1.05           2.3015 -1.251500e+00
# 185          0.25           0.3666 -1.166000e-01
# 250         12.90           9.2731  3.626900e+00
# 287          5.75           4.7777  9.723000e-01
# 152          0.50           0.4806  1.940000e-02
# 7            6.50           6.5420 -4.200000e-02
# 211         11.75           9.2810  2.469000e+00
# 209          4.85           5.1565 -3.065000e-01
# 205          5.25           5.3370 -8.700000e-02
# 290          4.50           5.1085 -6.085000e-01
# 244          5.95           5.6393  3.107000e-01
# 285          7.40           6.7683  6.317000e-01
# 114          1.15           1.1280  2.200000e-02
# 271          3.00           3.2324 -2.324000e-01
# 221          4.50           3.9460  5.540000e-01
# 55           3.60           3.8404 -2.404000e-01
# 241          4.75           4.2385  5.115000e-01
# 150          0.50           0.5000  4.440892e-16
# 207          5.15           4.0690  1.081000e+00
# 237         11.25           8.1846  3.065400e+00
# 72           7.45           6.9560  4.940000e-01
# 256         10.25           9.0551  1.194900e+00
# 137          0.65           0.5242  1.258000e-01
# 255          3.00           3.2080 -2.080000e-01
# 248          4.00           2.8515  1.148500e+00
# 42           1.95           2.5432 -5.932000e-01
# 154          0.50           0.5980 -9.800000e-02
# 68           4.35           4.9051 -5.551000e-01
# 116          1.10           1.0603  3.970000e-02
# 24           2.90           2.5360  3.640000e-01

# %%
# Create plot
plt.figure(figsize=(10, 5))
sns.regplot(x=y_test, y=y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Prices vs Predicted Prices")
plt.show()

# %% [markdown]
# **Best** **Model**

# %% [markdown]
# Best model is random Forest regressor
# * MSE:1.58 (vs Decision Tree's 1.82) ___ More precise predictions
# * R2: 92.8% (vs Decision Tree's 91.7%)__ Better fit to data
#
# More stable than single  Decision Tree (reduce overfitting risk)

# %% [markdown]
# **Conclusion**
#
# Random Forest delivers the most accurate and reliable car price predictions.
